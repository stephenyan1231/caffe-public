# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import leveldb
import lmdb
import time

caffe_root = os.environ['CAFFE_PROJ_DIR']
print 'caffe_root ',caffe_root
sys.path.insert(0, caffe_root + 'python')
sys.path.append(caffe_root + 'python/util')
import caffe
from util_func import *

sys.path.append(caffe_root + 'python/caffe/proto')
import caffe_pb2

# Set the right path to your model definition file, pretrained model weights,
# and the image you would like to classify.

'''HDCNN (ImageNet-NIN)'''
model_dir=caffe_root+'models/nin_imagenet/89clusters/89clusters_v2.0/'
MODEL_FILE =model_dir + 'hdcnn_deploy.prototxt'
PRETRAINED = model_dir + 'hdcnn_iter_0.caffemodel'
raw_scale=255

example_dir=caffe_root+'examples/imagenet/'
data_dir=caffe_root+'data/ilsvrc12/'
print 'model_dir ',model_dir
print 'example_dir ',example_dir
print 'data_dir ',data_dir
# Out:
# caffe_root  /home/zyan3/proj/caffe_private_hdcnn/
# model_dir  /home/zyan3/proj/caffe_private_hdcnn/models/nin_imagenet/89clusters/89clusters_v2.0/
# example_dir  /home/zyan3/proj/caffe_private_hdcnn/examples/imagenet/
# data_dir  /home/zyan3/proj/caffe_private_hdcnn/data/ilsvrc12/

# %%
label_names=read_text(data_dir + 'synset_words.txt')
num_class=len(label_names)
print 'num_class: %d' % num_class
# Out:
# num_class: 1000

# %%
caffe.set_mode_gpu()
caffe.init_device(0)
# caffe.init_device(1)

# %%
# when loading individual images using caffe.io.load_image, channel_swap=(2,1,0)
# when loading images from preprocessed database, channel_swap=(0,1,2)
net = caffe.Classifier(MODEL_FILE, PRETRAINED,
                       mean=np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy'),
                       channel_swap=(0,1,2),
                       raw_scale=raw_scale,
                       image_dims=(256,256))

# %%
val_img_list_fn = data_dir + 'val.txt'
val_img_names, val_img_labels=read_val_image_list(val_img_list_fn)
num_val = len(val_img_names)
# Out:
# 50000 validation images

# %%
val_lmdb_fn = '/home/zyan3/local/data/imagenet/ilsvrc12/ilsvrc12_val_size_256_lmdb'
val_lmdb = lmdb.open(val_lmdb_fn)
txn=val_lmdb.begin()

# %%
num_val = 50000
batch_size = 500


batch_num = num_val / batch_size

topk=[1,5]
topk_accu_central_crop={}
topk_accu_10_view={}
for k in topk:
    topk_accu_central_crop[str(k)]=0
    topk_accu_10_view[str(k)]=0

pred_labels_central_crop = np.zeros((num_val),dtype=np.int32)
pred_labels_10_view = np.zeros((num_val),dtype=np.int32)

'''in the case of fine2multicoarse, need to do L1 normalization to make prediction a valid probability distribution'''
prediction_single=np.zeros((num_val, num_class), dtype=np.single)
prediction_multi=np.zeros((num_val, num_class), dtype=np.single)
gt_labels=np.zeros((num_val),dtype=np.int32)

for i in range(batch_num):
    print 'batch %d out of %d' % (i+1, batch_num)
    start, end = i*batch_size,(i+1)*batch_size
    
    test_imgs =[]
    test_img_labels=[]
    for j in range(start,end):
        key = '%s' %(val_img_names[j])
        string_data=txn.get(key)
        datum = caffe_pb2.Datum()
        datum.ParseFromString(string_data)    
        data_array = np.fromstring(datum.data, dtype=np.uint8) 
        data_array = np.float32(data_array)    
        data_array = data_array.reshape((datum.channels, datum.height, datum.width))
        data_array = np.transpose(data_array,(1,2,0))
        data_array /= 255.0
        test_imgs += [data_array]
        test_img_labels += [datum.label]
    gt_labels[start:end]=np.asarray(test_img_labels)
    
    '''single view test'''
    st_time=time.time()
    prediction = net.predict(test_imgs, oversample = False)
    prediction_single[start:end, :]=prediction
    
    pred_labels = np.zeros((batch_size, max(topk)),dtype=np.int32)
    for j in range(batch_size):
        idx=np.argsort(prediction[j,:])[::-1]
        pred_labels[j,:]=idx[:max(topk)]
    pred_labels_central_crop[start:end]=pred_labels[:,0]
        
    batch_topk_accu, batch_topk_guesses = top_k_accuracy(pred_labels, test_img_labels, topk)
    for key, value in batch_topk_accu.iteritems():
        topk_accu_central_crop[key] += value
    ep_time=time.time()-st_time
    print 'single view test elapsed time %3.2f seconds. top %d accu %4.3f top %d accuracy %4.3f' % \
    (ep_time,topk[0],batch_topk_accu[str(topk[0])], topk[-1],batch_topk_accu[str(topk[-1])])
    
    '''10-view test'''
    st_time=time.time()
    prediction = net.predict(test_imgs, oversample = True)
    prediction_multi[start:end,:]=prediction
    pred_labels = np.zeros((batch_size, max(topk)),dtype=np.int32)
    for j in range(batch_size):
        idx=np.argsort(prediction[j,:])[::-1]
        pred_labels[j,:]=idx[:max(topk)]
    pred_labels_10_view[start:end]=pred_labels[:,0]
    
    batch_topk_accu, batch_topk_guesses = top_k_accuracy(pred_labels, test_img_labels, topk)
    for key, value in batch_topk_accu.iteritems():
        topk_accu_10_view[key] += value
    ep_time=time.time()-st_time
    print '10-view test elapsed time %3.2f seconds. top %d accu %4.3f top %d accuracy %4.3f' % \
    (ep_time,topk[0],batch_topk_accu[str(topk[0])], topk[-1],batch_topk_accu[str(topk[-1])])
    
print '-----------results-----------'
for key, value in topk_accu_central_crop.iteritems():
    topk_accu_central_crop[key]/=batch_num
    print 'w/o oversample top %s accuracy: %5.4f' % (key,topk_accu_central_crop[key])
    topk_accu_10_view[key]/=batch_num
    print 'with 10-view oversample top %s accuracy: %5.4f' % (key,topk_accu_10_view[key])

'''save prediction data into file'''
net_prediction={}
net_prediction['single']=prediction_single
net_prediction['multi']=prediction_multi
net_prediction['gt_labels']=gt_labels
pickle(model_dir + 'net_predictions', net_prediction)
# Out:
# batch 1 out of 100
# single view test elapsed time 44.25 seconds. top 1 accu 0.648 top 5 accuracy 0.872
# 10-view test elapsed time 414.48 seconds. top 1 accu 0.662 top 5 accuracy 0.872
# batch 2 out of 100
# single view test elapsed time 43.68 seconds. top 1 accu 0.608 top 5 accuracy 0.824
# 10-view test elapsed time 413.90 seconds. top 1 accu 0.620 top 5 accuracy 0.830
# batch 3 out of 100
# single view test elapsed time 43.64 seconds. top 1 accu 0.644 top 5 accuracy 0.832
# 10-view test elapsed time 413.82 seconds. top 1 accu 0.652 top 5 accuracy 0.858
# batch 4 out of 100
# single view test elapsed time 44.71 seconds. top 1 accu 0.582 top 5 accuracy 0.802
# 10-view test elapsed time 414.01 seconds. top 1 accu 0.602 top 5 accuracy 0.810
# batch 5 out of 100
# single view test elapsed time 43.70 seconds. top 1 accu 0.636 top 5 accuracy 0.840
# 10-view test elapsed time 413.89 seconds. top 1 accu 0.656 top 5 accuracy 0.860
# batch 6 out of 100
# single view test elapsed time 43.62 seconds. top 1 accu 0.628 top 5 accuracy 0.820
# 10-view test elapsed time 413.85 seconds. top 1 accu 0.654 top 5 accuracy 0.828
# batch 7 out of 100
# single view test elapsed time 43.63 seconds. top 1 accu 0.640 top 5 accuracy 0.854
# 10-view test elapsed time 413.91 seconds. top 1 accu 0.654 top 5 accuracy 0.864
# batch 8 out of 100
# single view test elapsed time 43.64 seconds. top 1 accu 0.634 top 5 accuracy 0.818
# 10-view test elapsed time 413.83 seconds. top 1 accu 0.654 top 5 accuracy 0.826
# batch 9 out of 100
# single view test elapsed time 43.66 seconds. top 1 accu 0.598 top 5 accuracy 0.826
# 10-view test elapsed time 413.65 seconds. top 1 accu 0.610 top 5 accuracy 0.828
# batch 10 out of 100
# single view test elapsed time 43.61 seconds. top 1 accu 0.660 top 5 accuracy 0.838
# 10-view test elapsed time 413.50 seconds. top 1 accu 0.670 top 5 accuracy 0.832
# batch 11 out of 100
# single view test elapsed time 43.58 seconds. top 1 accu 0.584 top 5 accuracy 0.802
# 10-view test elapsed time 413.54 seconds. top 1 accu 0.614 top 5 accuracy 0.808
# batch 12 out of 100
# single view test elapsed time 43.57 seconds. top 1 accu 0.610 top 5 accuracy 0.828
# 10-view test elapsed time 413.49 seconds. top 1 accu 0.634 top 5 accuracy 0.836
# batch 13 out of 100
# single view test elapsed time 44.65 seconds. top 1 accu 0.624 top 5 accuracy 0.828
# 10-view test elapsed time 418.12 seconds. top 1 accu 0.634 top 5 accuracy 0.844
# batch 14 out of 100
# single view test elapsed time 44.62 seconds. top 1 accu 0.640 top 5 accuracy 0.842
# 10-view test elapsed time 420.12 seconds. top 1 accu 0.662 top 5 accuracy 0.844
# batch 15 out of 100
# single view test elapsed time 44.18 seconds. top 1 accu 0.654 top 5 accuracy 0.864
# 10-view test elapsed time 418.49 seconds. top 1 accu 0.640 top 5 accuracy 0.866
# batch 16 out of 100
# single view test elapsed time 43.94 seconds. top 1 accu 0.606 top 5 accuracy 0.844
# 10-view test elapsed time 416.62 seconds. top 1 accu 0.624 top 5 accuracy 0.854
# batch 17 out of 100
# single view test elapsed time 44.43 seconds. top 1 accu 0.646 top 5 accuracy 0.830
# 10-view test elapsed time 416.34 seconds. top 1 accu 0.662 top 5 accuracy 0.838
# batch 18 out of 100
# single view test elapsed time 44.15 seconds. top 1 accu 0.586 top 5 accuracy 0.834
# 10-view test elapsed time 416.78 seconds. top 1 accu 0.602 top 5 accuracy 0.846
# batch 19 out of 100
# single view test elapsed time 43.98 seconds. top 1 accu 0.664 top 5 accuracy 0.840
# 10-view test elapsed time 415.70 seconds. top 1 accu 0.692 top 5 accuracy 0.862
# batch 20 out of 100
# single view test elapsed time 43.78 seconds. top 1 accu 0.630 top 5 accuracy 0.822
# 10-view test elapsed time 421.98 seconds. top 1 accu 0.648 top 5 accuracy 0.820
# batch 21 out of 100
# single view test elapsed time 44.74 seconds. top 1 accu 0.632 top 5 accuracy 0.834
# 10-view test elapsed time 415.55 seconds. top 1 accu 0.634 top 5 accuracy 0.838
# batch 22 out of 100
# single view test elapsed time 43.92 seconds. top 1 accu 0.604 top 5 accuracy 0.836
# 10-view test elapsed time 416.25 seconds. top 1 accu 0.626 top 5 accuracy 0.842
# batch 23 out of 100
# single view test elapsed time 43.86 seconds. top 1 accu 0.644 top 5 accuracy 0.824
# 10-view test elapsed time 414.75 seconds. top 1 accu 0.654 top 5 accuracy 0.842
# batch 24 out of 100
# single view test elapsed time 43.73 seconds. top 1 accu 0.610 top 5 accuracy 0.816
# 10-view test elapsed time 414.04 seconds. top 1 accu 0.624 top 5 accuracy 0.822
# batch 25 out of 100
# single view test elapsed time 44.75 seconds. top 1 accu 0.648 top 5 accuracy 0.864
# 10-view test elapsed time 419.01 seconds. top 1 accu 0.654 top 5 accuracy 0.878
# batch 26 out of 100
# single view test elapsed time 44.77 seconds. top 1 accu 0.620 top 5 accuracy 0.830
# 10-view test elapsed time 414.10 seconds. top 1 accu 0.614 top 5 accuracy 0.838
# batch 27 out of 100
# single view test elapsed time 43.99 seconds. top 1 accu 0.582 top 5 accuracy 0.820
# 10-view test elapsed time 414.90 seconds. top 1 accu 0.606 top 5 accuracy 0.836
# batch 28 out of 100
# single view test elapsed time 43.88 seconds. top 1 accu 0.644 top 5 accuracy 0.836
# 10-view test elapsed time 414.95 seconds. top 1 accu 0.636 top 5 accuracy 0.844
# batch 29 out of 100
# single view test elapsed time 43.89 seconds. top 1 accu 0.608 top 5 accuracy 0.826
# 10-view test elapsed time 414.95 seconds. top 1 accu 0.634 top 5 accuracy 0.830
# batch 30 out of 100
# single view test elapsed time 44.15 seconds. top 1 accu 0.616 top 5 accuracy 0.818
# 10-view test elapsed time 415.06 seconds. top 1 accu 0.626 top 5 accuracy 0.818
# batch 31 out of 100
# single view test elapsed time 43.90 seconds. top 1 accu 0.644 top 5 accuracy 0.838
# 10-view test elapsed time 414.97 seconds. top 1 accu 0.644 top 5 accuracy 0.860
# batch 32 out of 100
# single view test elapsed time 44.83 seconds. top 1 accu 0.620 top 5 accuracy 0.852
# 10-view test elapsed time 419.46 seconds. top 1 accu 0.658 top 5 accuracy 0.844
# batch 33 out of 100
# single view test elapsed time 43.83 seconds. top 1 accu 0.584 top 5 accuracy 0.816
# 10-view test elapsed time 415.25 seconds. top 1 accu 0.588 top 5 accuracy 0.832
# batch 34 out of 100
# single view test elapsed time 43.82 seconds. top 1 accu 0.634 top 5 accuracy 0.852
# 10-view test elapsed time 414.87 seconds. top 1 accu 0.640 top 5 accuracy 0.852
# batch 35 out of 100
# single view test elapsed time 43.92 seconds. top 1 accu 0.638 top 5 accuracy 0.826
# 10-view test elapsed time 414.73 seconds. top 1 accu 0.650 top 5 accuracy 0.848
# batch 36 out of 100
# single view test elapsed time 43.82 seconds. top 1 accu 0.608 top 5 accuracy 0.850
# 10-view test elapsed time 415.07 seconds. top 1 accu 0.612 top 5 accuracy 0.850
# batch 37 out of 100
# single view test elapsed time 43.82 seconds. top 1 accu 0.590 top 5 accuracy 0.832
# 10-view test elapsed time 414.90 seconds. top 1 accu 0.598 top 5 accuracy 0.840
# batch 38 out of 100
# single view test elapsed time 43.90 seconds. top 1 accu 0.622 top 5 accuracy 0.862
# 10-view test elapsed time 415.00 seconds. top 1 accu 0.606 top 5 accuracy 0.866
# batch 39 out of 100
# single view test elapsed time 43.95 seconds. top 1 accu 0.610 top 5 accuracy 0.848
# 10-view test elapsed time 415.20 seconds. top 1 accu 0.642 top 5 accuracy 0.856
# batch 40 out of 100
# single view test elapsed time 44.82 seconds. top 1 accu 0.614 top 5 accuracy 0.834
# 10-view test elapsed time 414.99 seconds. top 1 accu 0.646 top 5 accuracy 0.840
# batch 41 out of 100
# single view test elapsed time 44.75 seconds. top 1 accu 0.622 top 5 accuracy 0.842
# 10-view test elapsed time 415.06 seconds. top 1 accu 0.632 top 5 accuracy 0.840
# batch 42 out of 100
# single view test elapsed time 43.78 seconds. top 1 accu 0.664 top 5 accuracy 0.842
# 10-view test elapsed time 414.89 seconds. top 1 accu 0.668 top 5 accuracy 0.848
# batch 43 out of 100
# single view test elapsed time 43.84 seconds. top 1 accu 0.610 top 5 accuracy 0.860
# 10-view test elapsed time 415.00 seconds. top 1 accu 0.630 top 5 accuracy 0.866
# batch 44 out of 100
# single view test elapsed time 43.78 seconds. top 1 accu 0.624 top 5 accuracy 0.864
# 10-view test elapsed time 415.10 seconds. top 1 accu 0.636 top 5 accuracy 0.876
# batch 45 out of 100
# single view test elapsed time 43.80 seconds. top 1 accu 0.600 top 5 accuracy 0.808
# 10-view test elapsed time 415.04 seconds. top 1 accu 0.616 top 5 accuracy 0.834
# batch 46 out of 100
# single view test elapsed time 43.83 seconds. top 1 accu 0.612 top 5 accuracy 0.842
# 10-view test elapsed time 415.18 seconds. top 1 accu 0.630 top 5 accuracy 0.854
# batch 47 out of 100
# single view test elapsed time 44.29 seconds. top 1 accu 0.634 top 5 accuracy 0.840
# 10-view test elapsed time 415.05 seconds. top 1 accu 0.636 top 5 accuracy 0.844
# batch 48 out of 100
# single view test elapsed time 43.82 seconds. top 1 accu 0.574 top 5 accuracy 0.812
# 10-view test elapsed time 415.14 seconds. top 1 accu 0.568 top 5 accuracy 0.820
# batch 49 out of 100
# single view test elapsed time 43.87 seconds. top 1 accu 0.622 top 5 accuracy 0.846
# 10-view test elapsed time 415.19 seconds. top 1 accu 0.640 top 5 accuracy 0.856
# batch 50 out of 100
# single view test elapsed time 43.82 seconds. top 1 accu 0.612 top 5 accuracy 0.848
# 10-view test elapsed time 418.33 seconds. top 1 accu 0.638 top 5 accuracy 0.844
# batch 51 out of 100
# single view test elapsed time 43.94 seconds. top 1 accu 0.628 top 5 accuracy 0.824
# 10-view test elapsed time 415.30 seconds. top 1 accu 0.648 top 5 accuracy 0.842
# batch 52 out of 100
# single view test elapsed time 44.38 seconds. top 1 accu 0.616 top 5 accuracy 0.844
# 10-view test elapsed time 419.06 seconds. top 1 accu 0.630 top 5 accuracy 0.850
# batch 53 out of 100
# single view test elapsed time 45.82 seconds. top 1 accu 0.618 top 5 accuracy 0.830
# 10-view test elapsed time 422.51 seconds. top 1 accu 0.612 top 5 accuracy 0.862
# batch 54 out of 100
# single view test elapsed time 45.05 seconds. top 1 accu 0.640 top 5 accuracy 0.818
# 10-view test elapsed time 418.54 seconds. top 1 accu 0.654 top 5 accuracy 0.820
# batch 55 out of 100
# single view test elapsed time 43.89 seconds. top 1 accu 0.594 top 5 accuracy 0.816
# 10-view test elapsed time 414.84 seconds. top 1 accu 0.610 top 5 accuracy 0.816
# batch 56 out of 100
# single view test elapsed time 43.72 seconds. top 1 accu 0.598 top 5 accuracy 0.842
# 10-view test elapsed time 414.40 seconds. top 1 accu 0.628 top 5 accuracy 0.866
# batch 57 out of 100
# single view test elapsed time 43.72 seconds. top 1 accu 0.644 top 5 accuracy 0.832
# 10-view test elapsed time 414.45 seconds. top 1 accu 0.668 top 5 accuracy 0.858
# batch 58 out of 100
# single view test elapsed time 44.78 seconds. top 1 accu 0.630 top 5 accuracy 0.838
# 10-view test elapsed time 419.22 seconds. top 1 accu 0.640 top 5 accuracy 0.844
# batch 59 out of 100
# single view test elapsed time 44.95 seconds. top 1 accu 0.612 top 5 accuracy 0.826
# 10-view test elapsed time 414.92 seconds. top 1 accu 0.626 top 5 accuracy 0.820
# batch 60 out of 100
# single view test elapsed time 43.78 seconds. top 1 accu 0.668 top 5 accuracy 0.840
# 10-view test elapsed time 414.97 seconds. top 1 accu 0.684 top 5 accuracy 0.848
# batch 61 out of 100
# single view test elapsed time 44.72 seconds. top 1 accu 0.626 top 5 accuracy 0.834
# 10-view test elapsed time 414.87 seconds. top 1 accu 0.634 top 5 accuracy 0.842
# batch 62 out of 100
# single view test elapsed time 43.87 seconds. top 1 accu 0.606 top 5 accuracy 0.816
# 10-view test elapsed time 416.16 seconds. top 1 accu 0.614 top 5 accuracy 0.838
# batch 63 out of 100
# single view test elapsed time 43.87 seconds. top 1 accu 0.616 top 5 accuracy 0.828
# 10-view test elapsed time 414.81 seconds. top 1 accu 0.644 top 5 accuracy 0.828
# batch 64 out of 100
# single view test elapsed time 43.76 seconds. top 1 accu 0.652 top 5 accuracy 0.850
# 10-view test elapsed time 416.68 seconds. top 1 accu 0.646 top 5 accuracy 0.854
# batch 65 out of 100
# single view test elapsed time 43.78 seconds. top 1 accu 0.610 top 5 accuracy 0.850
# 10-view test elapsed time 414.72 seconds. top 1 accu 0.628 top 5 accuracy 0.858
# batch 66 out of 100
# single view test elapsed time 43.82 seconds. top 1 accu 0.570 top 5 accuracy 0.802
# 10-view test elapsed time 414.88 seconds. top 1 accu 0.586 top 5 accuracy 0.800
# batch 67 out of 100
# single view test elapsed time 44.74 seconds. top 1 accu 0.628 top 5 accuracy 0.848
# 10-view test elapsed time 414.67 seconds. top 1 accu 0.656 top 5 accuracy 0.862
# batch 68 out of 100
# single view test elapsed time 43.84 seconds. top 1 accu 0.586 top 5 accuracy 0.824
# 10-view test elapsed time 415.44 seconds. top 1 accu 0.592 top 5 accuracy 0.822
# batch 69 out of 100
# single view test elapsed time 43.87 seconds. top 1 accu 0.626 top 5 accuracy 0.820
# 10-view test elapsed time 415.00 seconds. top 1 accu 0.638 top 5 accuracy 0.830
# batch 70 out of 100
# single view test elapsed time 44.82 seconds. top 1 accu 0.640 top 5 accuracy 0.862
# 10-view test elapsed time 415.04 seconds. top 1 accu 0.658 top 5 accuracy 0.866
# batch 71 out of 100
# single view test elapsed time 43.83 seconds. top 1 accu 0.630 top 5 accuracy 0.834
# 10-view test elapsed time 414.61 seconds. top 1 accu 0.632 top 5 accuracy 0.852
# batch 72 out of 100
# single view test elapsed time 43.68 seconds. top 1 accu 0.630 top 5 accuracy 0.826
# 10-view test elapsed time 413.74 seconds. top 1 accu 0.644 top 5 accuracy 0.836
# batch 73 out of 100
# single view test elapsed time 43.68 seconds. top 1 accu 0.668 top 5 accuracy 0.844
# 10-view test elapsed time 413.98 seconds. top 1 accu 0.680 top 5 accuracy 0.854
# batch 74 out of 100
# single view test elapsed time 43.66 seconds. top 1 accu 0.584 top 5 accuracy 0.840
# 10-view test elapsed time 413.92 seconds. top 1 accu 0.594 top 5 accuracy 0.852
# batch 75 out of 100
# single view test elapsed time 44.69 seconds. top 1 accu 0.626 top 5 accuracy 0.818
# 10-view test elapsed time 413.82 seconds. top 1 accu 0.632 top 5 accuracy 0.830
# batch 76 out of 100
# single view test elapsed time 44.71 seconds. top 1 accu 0.620 top 5 accuracy 0.814
# 10-view test elapsed time 419.02 seconds. top 1 accu 0.634 top 5 accuracy 0.840
# batch 77 out of 100
# single view test elapsed time 43.67 seconds. top 1 accu 0.640 top 5 accuracy 0.848
# 10-view test elapsed time 413.88 seconds. top 1 accu 0.658 top 5 accuracy 0.864
# batch 78 out of 100
# single view test elapsed time 43.65 seconds. top 1 accu 0.616 top 5 accuracy 0.834
# 10-view test elapsed time 413.92 seconds. top 1 accu 0.620 top 5 accuracy 0.836
# batch 79 out of 100
# single view test elapsed time 43.66 seconds. top 1 accu 0.620 top 5 accuracy 0.826
# 10-view test elapsed time 414.32 seconds. top 1 accu 0.636 top 5 accuracy 0.848
# batch 80 out of 100
# single view test elapsed time 43.66 seconds. top 1 accu 0.638 top 5 accuracy 0.834
# 10-view test elapsed time 414.14 seconds. top 1 accu 0.638 top 5 accuracy 0.832
# batch 81 out of 100
# single view test elapsed time 43.70 seconds. top 1 accu 0.620 top 5 accuracy 0.856
# 10-view test elapsed time 414.01 seconds. top 1 accu 0.644 top 5 accuracy 0.868
# batch 82 out of 100
# single view test elapsed time 43.62 seconds. top 1 accu 0.596 top 5 accuracy 0.830
# 10-view test elapsed time 414.08 seconds. top 1 accu 0.604 top 5 accuracy 0.824
# batch 83 out of 100
# single view test elapsed time 43.64 seconds. top 1 accu 0.604 top 5 accuracy 0.834
# 10-view test elapsed time 417.67 seconds. top 1 accu 0.616 top 5 accuracy 0.854
# batch 84 out of 100
# single view test elapsed time 43.65 seconds. top 1 accu 0.604 top 5 accuracy 0.830
# 10-view test elapsed time 414.04 seconds. top 1 accu 0.614 top 5 accuracy 0.838
# batch 85 out of 100
# single view test elapsed time 44.71 seconds. top 1 accu 0.638 top 5 accuracy 0.846
# 10-view test elapsed time 413.94 seconds. top 1 accu 0.644 top 5 accuracy 0.846
# batch 86 out of 100
# single view test elapsed time 43.69 seconds. top 1 accu 0.592 top 5 accuracy 0.830
# 10-view test elapsed time 413.92 seconds. top 1 accu 0.616 top 5 accuracy 0.818
# batch 87 out of 100
# single view test elapsed time 43.70 seconds. top 1 accu 0.624 top 5 accuracy 0.832
# 10-view test elapsed time 413.82 seconds. top 1 accu 0.642 top 5 accuracy 0.836
# batch 88 out of 100
# single view test elapsed time 43.67 seconds. top 1 accu 0.602 top 5 accuracy 0.836
# 10-view test elapsed time 413.93 seconds. top 1 accu 0.610 top 5 accuracy 0.844
# batch 89 out of 100
# single view test elapsed time 43.69 seconds. top 1 accu 0.620 top 5 accuracy 0.840
# 10-view test elapsed time 413.94 seconds. top 1 accu 0.646 top 5 accuracy 0.840
# batch 90 out of 100
# single view test elapsed time 43.69 seconds. top 1 accu 0.612 top 5 accuracy 0.822
# 10-view test elapsed time 414.43 seconds. top 1 accu 0.622 top 5 accuracy 0.824
# batch 91 out of 100
# single view test elapsed time 43.65 seconds. top 1 accu 0.622 top 5 accuracy 0.830
# 10-view test elapsed time 413.89 seconds. top 1 accu 0.634 top 5 accuracy 0.838
# batch 92 out of 100
# single view test elapsed time 43.69 seconds. top 1 accu 0.642 top 5 accuracy 0.862
# 10-view test elapsed time 414.05 seconds. top 1 accu 0.640 top 5 accuracy 0.852
# batch 93 out of 100
# single view test elapsed time 43.62 seconds. top 1 accu 0.616 top 5 accuracy 0.820
# 10-view test elapsed time 413.98 seconds. top 1 accu 0.630 top 5 accuracy 0.836
# batch 94 out of 100
# single view test elapsed time 43.71 seconds. top 1 accu 0.628 top 5 accuracy 0.828
# 10-view test elapsed time 414.07 seconds. top 1 accu 0.648 top 5 accuracy 0.832
# batch 95 out of 100
# single view test elapsed time 43.65 seconds. top 1 accu 0.596 top 5 accuracy 0.840
# 10-view test elapsed time 414.18 seconds. top 1 accu 0.630 top 5 accuracy 0.842
# batch 96 out of 100
# single view test elapsed time 43.63 seconds. top 1 accu 0.646 top 5 accuracy 0.838
# 10-view test elapsed time 413.93 seconds. top 1 accu 0.652 top 5 accuracy 0.842
# batch 97 out of 100
# single view test elapsed time 44.68 seconds. top 1 accu 0.628 top 5 accuracy 0.820
# 10-view test elapsed time 418.69 seconds. top 1 accu 0.652 top 5 accuracy 0.838
# batch 98 out of 100
# single view test elapsed time 43.62 seconds. top 1 accu 0.630 top 5 accuracy 0.836
# 10-view test elapsed time 413.94 seconds. top 1 accu 0.642 top 5 accuracy 0.844
# batch 99 out of 100
# single view test elapsed time 43.63 seconds. top 1 accu 0.634 top 5 accuracy 0.822
# 10-view test elapsed time 414.06 seconds. top 1 accu 0.656 top 5 accuracy 0.834
# batch 100 out of 100
# single view test elapsed time 44.71 seconds. top 1 accu 0.630 top 5 accuracy 0.834
# 10-view test elapsed time 418.90 seconds. top 1 accu 0.642 top 5 accuracy 0.852
# -----------results-----------
# w/o oversample top 1 accuracy: 0.6213
# with 10-view oversample top 1 accuracy: 0.6348
# w/o oversample top 5 accuracy: 0.8343
# with 10-view oversample top 5 accuracy: 0.8426
