# %% [markdown]
# Here we visualize filters and outputs using the network architecture proposed by Krizhevsky et al. for ImageNet and implemented in `caffe`.
#
# (This page follows DeCAF visualizations originally by Yangqing Jia.)

# %% [markdown]
# First, import required modules, set plotting parameters, and run `./scripts/download_model_binary.py models/bvlc_reference_caffenet` to get the pretrained CaffeNet model if it hasn't already been fetched.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Make sure that caffe is on the python path:
caffe_root = '/home/zyan3/proj/caffe_private_multigpu/'  # this file is expected to be in {caffe_root}/examples
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

import os
if not os.path.isfile(caffe_root + 'models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel'):
    print("Downloading pre-trained CaffeNet model...")
    # !../scripts/download_model_binary.py ../models/bvlc_reference_caffenet

# %% [markdown]
# Set Caffe to CPU mode, load the net in the test phase for inference, and configure input preprocessing.

# %%
caffe.set_mode_gpu()
caffe.init_device(0)
caffe.init_device(1)
net = caffe.Net(caffe_root + 'models/VGG_ILSVRC_16_layers/211839e770f7b538e2d8/VGG_ILSVRC_16_layers_deploy.prototxt',
                caffe_root + 'models/VGG_ILSVRC_16_layers/211839e770f7b538e2d8/VGG_ILSVRC_16_layers.caffemodel')
# net = caffe.Net(caffe_root + 'models/bvlc_reference_caffenet/deploy.prototxt',
#                 caffe_root + 'models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel')
caffe.set_phase_test()

# %%
replica_id = 0
print net.blobs(replica_id)['data'].num
print net.blobs(replica_id)['data'].channels
print net.blobs(replica_id)['data'].height
print net.blobs(replica_id)['data'].width
# Out:
# 10
# 3
# 224
# 224

# %%
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs(0)['data'].data.shape})
transformer.set_transpose('data', (2,0,1))
transformer.set_mean('data', np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy').mean(1).mean(1)) # mean pixel
transformer.set_raw_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB

# %% [markdown]
# Classify the image by reshaping the net for the single input then doing the forward pass.

# %%
crop_size = [224, 224]
net.blobs(0)['data'].reshape(1,3,crop_size[0],crop_size[1])
net.blobs(0)['data'].data[...] = transformer.preprocess('data', caffe.io.load_image(caffe_root + 'examples/images/cat.jpg'))

net.blobs(1)['data'].reshape(1,3,crop_size[0],crop_size[1])
# AmericanPitBullTerrier
net.blobs(1)['data'].data[...] = transformer.preprocess('data', caffe.io.load_image(caffe_root + 'examples/images/AmericanPitBullTerrier.jpg'))

# %%
out = net.forward()

# %%
print out['prob'].shape
# Out:
# (2, 1000, 1, 1)

# %%
print("Predicted class is #{}.".format(out['prob'][0].argmax()))
print("Predicted class is #{}.".format(out['prob'][1].argmax()))
# Out:
# Predicted class is #278.
# Predicted class is #180.

# %% [markdown]
# The layer features and their shapes (1 is the batch size, corresponding to the single input image in this example).

# %%
[(k, v.data.shape) for k, v in net.blobs(0).items()]
# Out:
# [('data', (1, 3, 224, 224)),
#  ('conv1_1', (1, 64, 224, 224)),
#  ('conv1_2', (1, 64, 224, 224)),
#  ('pool1', (1, 64, 112, 112)),
#  ('conv2_1', (1, 128, 112, 112)),
#  ('conv2_2', (1, 128, 112, 112)),
#  ('pool2', (1, 128, 56, 56)),
#  ('conv3_1', (1, 256, 56, 56)),
#  ('conv3_2', (1, 256, 56, 56)),
#  ('conv3_3', (1, 256, 56, 56)),
#  ('pool3', (1, 256, 28, 28)),
#  ('conv4_1', (1, 512, 28, 28)),
#  ('conv4_2', (1, 512, 28, 28)),
#  ('conv4_3', (1, 512, 28, 28)),
#  ('pool4', (1, 512, 14, 14)),
#  ('conv5_1', (1, 512, 14, 14)),
#  ('conv5_2', (1, 512, 14, 14)),
#  ('conv5_3', (1, 512, 14, 14)),
#  ('pool5', (1, 512, 7, 7)),
#  ('fc6', (1, 4096, 1, 1)),
#  ('fc7', (1, 4096, 1, 1)),
#  ('fc8', (1, 1000, 1, 1)),
#  ('prob', (1, 1000, 1, 1))]

# %% [markdown]
# The parameters and their shapes. The parameters are `net.params['name'][0]` while biases are `net.params['name'][1]`.

# %%
[(k, v[0].data.shape) for k, v in net.params.items()]
# Out:
# [('conv1_1', (64, 3, 3, 3)),
#  ('conv1_2', (64, 64, 3, 3)),
#  ('conv2_1', (128, 64, 3, 3)),
#  ('conv2_2', (128, 128, 3, 3)),
#  ('conv3_1', (256, 128, 3, 3)),
#  ('conv3_2', (256, 256, 3, 3)),
#  ('conv3_3', (256, 256, 3, 3)),
#  ('conv4_1', (512, 256, 3, 3)),
#  ('conv4_2', (512, 512, 3, 3)),
#  ('conv4_3', (512, 512, 3, 3)),
#  ('conv5_1', (512, 512, 3, 3)),
#  ('conv5_2', (512, 512, 3, 3)),
#  ('conv5_3', (512, 512, 3, 3)),
#  ('fc6', (1, 1, 4096, 25088)),
#  ('fc7', (1, 1, 4096, 4096)),
#  ('fc8', (1, 1, 1000, 4096))]

# %% [markdown]
# Helper functions for visualization

# %%
# take an array of shape (n, height, width) or (n, height, width, channels)
# and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)
def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    plt.imshow(data)

# %% [markdown]
# The input image

# %%
plt.imshow(transformer.deprocess('data', net.blobs(0)['data'].data[0]))

# %%
plt.imshow(transformer.deprocess('data', net.blobs(1)['data'].data[0]))

# %% [markdown]
# The first layer filters, `conv1`

# %%
# the parameters are a list of [weights, biases]
filters = net.params['conv1_1'][0].data
vis_square(filters.transpose(0, 2, 3, 1))

# %% [markdown]
# The first layer output, `conv1` (rectified responses of the filters above, first 36 only)

# %%
feat = net.blobs(0)['conv1_1'].data[0, :64]
vis_square(feat, padval=1)

# %%
feat = net.blobs(1)['conv1_1'].data[0, :64]
vis_square(feat, padval=1)

# %% [markdown]
# The second layer filters, `conv2`
#
# There are 256 filters, each of which has dimension 5 x 5 x 48. We show only the first 48 filters, with each channel shown separately, so that each filter is a row.

# %%
print net.params['conv2_1'][0].data.shape
# Out:
# (128, 64, 3, 3)

# %%
filters = net.params['conv2_1'][0].data
vis_square(filters[:64].reshape(64**2, 3, 3))

# %% [markdown]
# The second layer output, `conv2` (rectified, only the first 36 of 256 channels)

# %%
feat = net.blobs(0)['conv2_1'].data[0, :64]
vis_square(feat, padval=1)

# %%
feat = net.blobs(1)['conv2_1'].data[0, :64]
vis_square(feat, padval=1)

# %% [markdown]
# The third layer output, `conv3` (rectified, all 384 channels)

# %%
feat = net.blobs(0)['conv3_1'].data[0]
vis_square(feat, padval=0.5)

# %%
feat = net.blobs(1)['conv3_1'].data[0]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fourth layer output, `conv4` (rectified, all 384 channels)

# %%
feat = net.blobs(0)['conv4_1'].data[0]
vis_square(feat, padval=0.5)

# %%
feat = net.blobs(1)['conv4_1'].data[0]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fifth layer output, `conv5` (rectified, all 256 channels)

# %%
feat = net.blobs(0)['conv5_1'].data[0]
vis_square(feat, padval=0.5)

# %%
feat = net.blobs(1)['conv5_1'].data[0]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fifth layer after pooling, `pool5`

# %%
feat = net.blobs(0)['pool5'].data[0]
vis_square(feat, padval=1)

# %%
feat = net.blobs(1)['pool5'].data[0]
vis_square(feat, padval=1)

# %% [markdown]
# The first fully connected layer, `fc6` (rectified)
#
# We show the output values and the histogram of the positive values

# %%
feat = net.blobs(0)['fc6'].data[0]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)

# %% [markdown]
# The second fully connected layer, `fc7` (rectified)

# %%
feat = net.blobs(0)['fc7'].data[0]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)

# %% [markdown]
# The final probability output, `prob`

# %%
feat = net.blobs(0)['prob'].data[0]
plt.plot(feat.flat)

# %% [markdown]
# Let's see the top 5 predicted labels.

# %%
# load labels
imagenet_labels_filename = caffe_root + 'data/ilsvrc12/synset_words.txt'
try:
    labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')
except:
    # !../data/ilsvrc12/get_ilsvrc_aux.sh
    labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')

# sort top k predictions from softmax output
top_k = net.blobs(0)['prob'].data[0].flatten().argsort()[-1:-6:-1]
print labels[top_k]

top_k = net.blobs(1)['prob'].data[0].flatten().argsort()[-1:-6:-1]
print labels[top_k]
# Out:
# ['n02119789 kit fox, Vulpes macrotis' 'n02119022 red fox, Vulpes vulpes'
#  'n02124075 Egyptian cat' 'n02123159 tiger cat'
#  'n02123045 tabby, tabby cat']
# [ 'n02093428 American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier'
#  'n02087394 Rhodesian ridgeback' 'n02109047 Great Dane'
#  'n02091244 Ibizan hound, Ibizan Podenco'
#  'n02107142 Doberman, Doberman pinscher']
